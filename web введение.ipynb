# %% [markdown]
# #
# 2 практика css и html
# нам на выходе хорошо бы получить приложение для микросхемы
#
# ппоставил модуль для автокомпиляции less в css
# Easy LESS
# Auto-compile LESS to CSS on save
#
#         Создайте файл в формате .less.
#         Нажмите Ctrl/Cmd+S, чтобы сохранить файл.
#         Файл .css будет создан автоматически.
#         СЛОЖНЫЕ СЦЕНАРИИ ВНУТРИ ОПИСАНИЯ НАМ НЕ НУЖНЫ ПОКА
#
# ВРОДЕ ПОДСВЕТКИ МОДУЛЬ VS CODE
# Beautify css/sass/scss/less
# 36:37 список расширений на экране
# мы ставим
#         Live Server
#         open in browser
#
# https://docs.emmet.io/
# https://html5css.ru/tags/default.php
# https://fish-text.ru/

# %% [markdown]
# 3 лабораторная js
#
# 1. Необходимо создать html-страницу с названием 1.html, в которой подключить файл 1.js
# (его тоже необходимо создать рядом с html-файлом). В js-файле необходимо создать следующий скрипт:
# Необходимо пользователя попросить ввести температуру в градусах Цельсия, преобразовать введенное пользователем значение в соответствующую температуру в градусах по Фаренгейту и вывести в alert сообщение с текстом (пример): Цельсий: 21, Фаренгейт: 69.8
# Где вместо 21 и 69.8 должны быть подставлены соответствующие значения, которые
# были получены ранее.
# Формула перевода градусов Цельсия в градусы Фаренгейта:
# градусы Фаренгейта = (9 / 5) * градусы Цельсия + 32
# Примечания: Пользователь всегда вводит корректное число.
# Советую округлить значение после расчетов, так как в некоторых случаях может получиться "длинная дробь".
#
# 2. Необходимо создать html-страницу с названием 2.html, в которой подключить файл 2.js (его тоже необходимо создать рядом с html-файлом). В js-файле необходимо создать следующий скрипт:
# Cоздать функцию greeting, которая принимает имя и выводит приветствие, используя переданное имя, в консоль.
# Необходимо у пользователя запросить имя и вызвать функцию greeting, передав туда данное значение.

# %%
4 лабораторная js
 
Задача №1: сформировать массив с данными для блока «Опыт работы».
Вывести данные массива в HTML-шаблоне.

Задача №2: создать БД, состоящую из одной таблицы (информация об одногруппниках) 
с четырьмя полями (добавить поле «Адрес»): id, name, age, address.

# %% [markdown]
# В конце 5 серии
# Совутую пользоваться парсерами:
# xml-парсер: https://jsonformatter.org/xml-formatter
# json-парсер: https://jsonformatter.org/json-parser

# %% [markdown]
# В ОБЩЕМ В ПАПКАХ КУЧА ПОЛЕЗНОГО МАТЕРИАЛА ДЛЯ ИЗУЧЕНИЯ
# ПОСЛЕДНЮЮ ПРАКТИКУ ТОЖЕ НАДО ДОСЛУШАТЬ.
